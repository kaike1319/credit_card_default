# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("default of credit card clients.xls", skiprows=[0], index_col=False)

# %% [markdown]
# ### Rename the columns

# %%
df.columns = ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE',
              'HIST_Sep', 'HIST_Aug', 'HIST_Jul', 'HIST_Jun', 'HIST_May', 'HIST_Apr', 
              'BILL_AMT_Sep', 'BILL_AMT_Aug', 'BILL_AMT_Jul', 'BILL_AMT_Jun', 'BILL_AMT_May', 'BILL_AMT_Apr',
              'PAY_AMT_Sep', 'PAY_AMT_Aug', 'PAY_AMT_Jul', 'PAY_AMT_Jun', 'PAY_AMT_May', 'PAY_AMT_Apr',
              'default payment next month']

# %% [markdown]
# ### Exploratory Analysis
